# %% [markdown]
# # Application Programming Interfaces (APIs) - Gathering Data Using Requests

# %% [markdown]
# ## Objectives
#
# - Send requests and receive responses over the web
# - Retrieve data from APIs using the `requests` library
# - Parse API responses

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"20625025959","type":"IssueCommentEvent","actor":{"id":1343915,"login":"triffon","display_login":"triffon","gravatar_id":"","url":"https://api.github.com/users/triffon","avatar_url":"https://avatars.githubusercontent.com/u/1343915?"},"repo":{"id":461452023,"name":"triffon/oop-2021-22","url":"https://api.github.com/repos/triffon/oop-2021-22"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/triffon/oop-2021-22/issues/1","repository_url":"https://api.github.com/repos/triffon/oop-2021-22","labels_url":"https://api.github.com/repos/triffon/oop-2021-22/issues/1/labels{/name}","comments_url":"https://api.github.com/repos/triffon/oop-2021-22/issues/1/comments","events_url":"https://api.github.com/repos/triffon/oop-2021-22/issues/1/events","html_url":"https://github.com/triffon/oop-2021-22/pull/1","id":1161809711,"node_id":"PR_kwDOG4Ey9840D-nj","number":1,"title":"Add Week-1 materials for group 7","user":{"login":"martinlakov","id":85170913,"node_id":"MDQ6VXNlcjg1MTcwOTEz","avatar_url":"https://avatars.githubusercontent.com/u/85170913?v=4","gravatar_id":"","url":"https://api.github.com/users/martinlakov","html_url":"https://github.com/martinlakov","followers_url":"https://api.github.com/users/martinlakov/followers","following_url":"https://api.github.com/users/martinlakov/following{/other_user}","gists_url":"https://api.github.com/users/martinlakov/gists{/gist_id}","starred_url":"https://api.github.com/users/martinlakov/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/martinlakov/subscriptions","organizations_url":"https://api.github.com/users/martinlakov/orgs","repos_url":"https://api.github.com/users/martinlakov/repos","events_url":"https://api.github.com/users/martinlakov/events{/privacy}","received_events_url":"https://api.github.com/users/martinlakov/received_events","type":"User","site_admin":false},"labels":[],"state":"closed","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":1,"created_at":"2022-03-07T19:06:28Z","updated_at":"2022-03-07T21:29:35Z","closed_at":"2022-03-07T21:29:06Z","author_association":"CONTRIBUTOR","active_lock_reason":null,"draft":false,"pull_request":{"url":"https://api.github.com/repos/triffon/oop-2021-22/pulls/1","html_url":"https://github.com/triffon/oop-2021-22/pull/1","diff_url":"https://github.com/triffon/oop-2021-22/pull/1.diff","patch_url":"https://github.com/triffon/oop-2021-22/pull/1.patch","merged_at":"2022-03-07T21:29:06Z"},"body":null,"reactions":{"url":"https://api.github.com/repos/triffon/oop-2021-22/issues/1/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"timeline_url":"https://api.github.com/repos/triffon/oop-2021-22/issues/1/timeline","performed_via_github_app":null},"comment":{"url":"https://api.github.com/repos/triffon/oop-2021-22/issues/comments/1061155589","html_url":"https://github.com/triffon/oop-2021-22/pull/1#issuecomment-1061155589","issue_url":"https://api.github.com/repos/triffon/oop-2021-22/issues/1","id":1061155589,"node_id":"IC_kwDOG4Ey984_P_MF","user":{"login":"triffon","id":1343915,"node_id":"MDQ6VXNlcjEzNDM5MTU=","avatar_url":"https://avatars.githubusercontent.com/u/1343915?v=4","gravatar_id":"","url":"https://api.github.com/users/triffon","html_url":"https://github.com/triffon","followers_url":"https://api.github.com/users/triffon/followers","following_url":"https://api.github.com/users/triffon/following{/other_user}","gists_url":"https://api.github.com/users/triffon/gists{/gist_id}","starred_url":"https://api.github.com/users/triffon/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/triffon/subscriptions","organizations_url":"https://api.github.com/users/triffon/orgs","repos_url":"https://api.github.com/users/triffon/repos","events_url":"https://api.github.com/users/triffon/events{/privacy}","received_events_url":"https://api.github.com/users/triffon/received_events","type":"User","site_admin":false},"create ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Mon, 07 Mar 2022 21:34:35 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"ee04aea114328d70dab35c104b64e2acc7bae8ae13f4d029eb44e9a776c98902"', 'Last-Modified': 'Mon, 07 Mar 2022 21:29:35 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1646692475', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'CB2C:2DEE:3004E95:74CC045:62267A6B'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '20625025959',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1343915,
#    'login': 'triffon',
#    'display_login': 'triffon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/triffon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1343915?'},
#   'repo': {'id': 461452023,
#    'name': 'triffon/oop-2021-22',
#    'url': 'https://api.github.com/repos/triffon/oop-2021-22'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/1',
#     'repository_url': 'https://api.github.com/repos/triffon/oop-2021-22',
#     'labels_url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/1/events',
#     'html_url': 'https://github.com/triffon/oop-2021-22/pull/1',
#     'id': 1161809711,
#     'node_id': 'PR_kwDOG4Ey9840D-nj',
#     'number': 1,
#     'title': 'Add Week-1 materials for group 7',
#     'user': {'login': 'martinlakov',
#      'id': 85170913,
#      'node_id': 'MDQ6VXNlcjg1MTcwOTEz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/85170913?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/martinlakov',
#      'html_url': 'https://github.com/martinlakov',
#      'followers_url': 'https://api.github.com/users/martinlakov/followers',
#      'following_url': 'https://api.github.com/users/martinlakov/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/martinlakov/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/martinlakov/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/martinlakov/subscriptions',
#      'organizations_url': 'https://api.github.com/users/martinlakov/orgs',
#      'repos_url': 'https://api.github.com/users/martinlakov/repos',
#      'events_url': 'https://api.github.com/users/martinlakov/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/martinlakov/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2022-03-07T19:06:28Z',
#     'updated_at': '2022-03-07T21:29:35Z',
#     'closed_at': '2022-03-07T21:29:06Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/triffon/oop-2021-22/pulls/1',
#      'html_url': 'https://github.com/triffon/oop-2021-22/pull/1',
#      'diff_url': 'https://github.com/triffon/oop-2021-22/pull/1.diff',
#      'patch_url': 'https://github.com/triffon/oop-2021-22/pull/1.patch',
#      'merged_at': '2022-03-07T21:29:06Z'},
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/1/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/1/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/comments/1061155589',
#     'html_url': 'https://github.com/triffon/oop-2021-22/pull/1#issuecomment-1061155589',
#     'issue_url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/1',
#     'id': 1061155589,
#     'node_id': 'IC_kwDOG4Ey984_P_MF',
#     'user': {'login': 'triffon',
#      'id': 1343915,
#      'node_id': 'MDQ6VXNlcjEzNDM5MTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1343915?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/triffon',
#      'html_url': 'https://github.com/triffon',
#      'followers_url': 'https://api.github.com/users/triffon/followers',
#      'following_url': 'https://api.github.com/users/triffon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/triffon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/triffon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/triffon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/triffon/orgs',
#      'repos_url': 'https://api.github.com/users/triffon/repos',
#      'events_url': 'https://api.github.com/users/triffon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/triffon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-03-07T21:29:35Z',
#     'updated_at': '2022-03-07T21:29:35Z',
#     'author_association': 'OWNER',
#     'body': 'Добавих те като сътрудник, вече можеш да пишеш директно в хранилището, без да се налага да пускаш PR.',
#     'reactions': {'url': 'https://api.github.com/repos/triffon/oop-2021-22/issues/comments/1061155589/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025973',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 267885403,
#    'name': 'Geniucker/wake',
#    'url': 'https://api.github.com/repos/Geniucker/wake'},
#   'payload': {'push_id': 9288818905,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f4210a07caceb0d10e8ac0fa4793002edb4d9768',
#    'before': '18473c57114690efebaf135dd0afa0602443e114',
#    'commits': [{'sha': 'f4210a07caceb0d10e8ac0fa4793002edb4d9768',
#      'author': {'email': 'AutoWakeUp@email.com', 'name': 'AutoWakeUp'},
#      'message': 'Successful Wake',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Geniucker/wake/commits/f4210a07caceb0d10e8ac0fa4793002edb4d9768'}]},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025960',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 264617472,
#    'name': 'motheronthepea/motheronthepea.github.io',
#    'url': 'https://api.github.com/repos/motheronthepea/motheronthepea.github.io'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/node-sass-7.0.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z',
#   'org': {'id': 65466551,
#    'login': 'motheronthepea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/motheronthepea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65466551?'}},
#  {'id': '20625025957',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 467265371,
#    'name': 'direwolf-github/ephemeral-ci-ebfd6470',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-ebfd6470'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025951',
#   'type': 'CreateEvent',
#   'actor': {'id': 8629094,
#    'login': 'ribeirovillar',
#    'display_login': 'ribeirovillar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ribeirovillar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8629094?'},
#   'repo': {'id': 466450071,
#    'name': 'ribeirovillar/alura-spring',
#    'url': 'https://api.github.com/repos/ribeirovillar/alura-spring'},
#   'payload': {'ref': 'main_old',
#    'ref_type': 'branch',
#    'master_branch': 'main_old',
#    'description': 'Spring Boot API REST: Construa uma API',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025952',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 467265382,
#    'name': 'direwolf-github/ephemeral-ci-0733c0a3',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-0733c0a3'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025972',
#   'type': 'PushEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 467265372,
#    'name': 'direwolf-github/ephemeral-ci-3ce2b588',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-3ce2b588'},
#   'payload': {'push_id': 9288818891,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '01424430bd901420b73fbf9911bcfe6a582e1335',
#    'before': '51e74532917a95bac89ab0bac9683eb406af53c0',
#    'commits': [{'sha': '01424430bd901420b73fbf9911bcfe6a582e1335',
#      'author': {'email': 'heroku-lifecycle+direwolf-github@salesforce.com',
#       'name': 'direwolf-github'},
#      'message': 'Direwolf commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-3ce2b588/commits/01424430bd901420b73fbf9911bcfe6a582e1335'}]},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025963',
#   'type': 'PushEvent',
#   'actor': {'id': 6089694,
#    'login': 'rukmal',
#    'display_login': 'rukmal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rukmal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6089694?'},
#   'repo': {'id': 18819978,
#    'name': 'rukmal/Resume',
#    'url': 'https://api.github.com/repos/rukmal/Resume'},
#   'payload': {'push_id': 9288818896,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '5a85fe47af856eeada737e3385bff9775412d69a',
#    'before': '88a5f59b1c189361c2f4b3605d45ac59f936d252',
#    'commits': [{'sha': '5a85fe47af856eeada737e3385bff9775412d69a',
#      'author': {'email': 'rukmal.weerawarana@gmail.com',
#       'name': 'Rukmal Weerawarana'},
#      'message': 'Leave ExtraHop',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rukmal/Resume/commits/5a85fe47af856eeada737e3385bff9775412d69a'}]},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025956',
#   'type': 'PushEvent',
#   'actor': {'id': 12305958,
#    'login': 'dashney',
#    'display_login': 'dashney',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dashney',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12305958?'},
#   'repo': {'id': 467229556,
#    'name': 'PDXBES/SWMM_FY_report',
#    'url': 'https://api.github.com/repos/PDXBES/SWMM_FY_report'},
#   'payload': {'push_id': 9288818890,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '86196016023ca78b736d6c35d50e3db1627171f4',
#    'before': 'df7f145d39af0e1174cfd1a91d9f774ae721d75f',
#    'commits': [{'sha': '86196016023ca78b736d6c35d50e3db1627171f4',
#      'author': {'email': 'daniel.ashney@portlandoregon.gov',
#       'name': 'dashney'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PDXBES/SWMM_FY_report/commits/86196016023ca78b736d6c35d50e3db1627171f4'}]},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z',
#   'org': {'id': 17836869,
#    'login': 'PDXBES',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PDXBES',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17836869?'}},
#  {'id': '20625025939',
#   'type': 'PushEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 467265368,
#    'name': 'direwolf-github/ephemeral-ci-c43d901b',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-c43d901b'},
#   'payload': {'push_id': 9288818887,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '715ae24d589688a7f688c900edcd5fcb3d89accd',
#    'before': '959596dd1d51791cad4078f9f130210d44eea366',
#    'commits': [{'sha': '715ae24d589688a7f688c900edcd5fcb3d89accd',
#      'author': {'email': 'heroku-lifecycle+direwolf-github@salesforce.com',
#       'name': 'direwolf-github'},
#      'message': 'Direwolf commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-c43d901b/commits/715ae24d589688a7f688c900edcd5fcb3d89accd'}]},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025908',
#   'type': 'PushEvent',
#   'actor': {'id': 40063938,
#    'login': 'cutmal',
#    'display_login': 'cutmal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cutmal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40063938?'},
#   'repo': {'id': 462925556,
#    'name': 'cutmal/wiki',
#    'url': 'https://api.github.com/repos/cutmal/wiki'},
#   'payload': {'push_id': 9288818870,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'ade3d1854cd6def6080df182e9b3b9a43987d0aa',
#    'before': 'cc75709593d29ae56ab9a1873e5065dec2589ec0',
#    'commits': [{'sha': 'be4884bac2ea58d30be296612dfedd4b12e0b12c',
#      'author': {'email': 'isaac.wuerth@outlook.com', 'name': 'isaac.wuerth'},
#      'message': 'docs: update OST/IncRes/Exercise/Week2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cutmal/wiki/commits/be4884bac2ea58d30be296612dfedd4b12e0b12c'},
#     {'sha': 'ade3d1854cd6def6080df182e9b3b9a43987d0aa',
#      'author': {'email': 'isaac.wuerth@outlook.com', 'name': 'isaac.wuerth'},
#      'message': 'docs: update OST/IncRes/Exercise/Week2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cutmal/wiki/commits/ade3d1854cd6def6080df182e9b3b9a43987d0aa'}]},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025958',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 329512285,
#    'name': 'yefoenix/RSSHub',
#    'url': 'https://api.github.com/repos/yefoenix/RSSHub'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/920',
#     'repository_url': 'https://api.github.com/repos/yefoenix/RSSHub',
#     'labels_url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/920/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/920/comments',
#     'events_url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/920/events',
#     'html_url': 'https://github.com/yefoenix/RSSHub/pull/920',
#     'id': 1155828660,
#     'node_id': 'PR_kwDOE6P1Xc4zwQ8B',
#     'number': 920,
#     'title': 'chore(deps): bump puppeteer from 11.0.0 to 13.4.1',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 3105807730,
#       'node_id': 'MDU6TGFiZWwzMTA1ODA3NzMw',
#       'url': 'https://api.github.com/repos/yefoenix/RSSHub/labels/Auto:%20whitelisted',
#       'name': 'Auto: whitelisted',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2022-03-01T21:19:42Z',
#     'updated_at': '2022-03-07T21:29:35Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/yefoenix/RSSHub/pulls/920',
#      'html_url': 'https://github.com/yefoenix/RSSHub/pull/920',
#      'diff_url': 'https://github.com/yefoenix/RSSHub/pull/920.diff',
#      'patch_url': 'https://github.com/yefoenix/RSSHub/pull/920.patch',
#      'merged_at': None},
#     'body': 'Bumps [puppeteer](https://github.com/puppeteer/puppeteer) from 11.0.0 to 13.4.1.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/puppeteer/puppeteer/releases">puppeteer\'s releases</a>.</em></p>\n<blockquote>\n<h2>13.4.1</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>regression in --user-data-dir handling (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/8060">#8060</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/85decdc28d7d2128e6d2946a72f4d99dd5dbb48a">85decdc</a>)</li>\n</ul>\n<h2>13.4.0</h2>\n<h3>Features</h3>\n<ul>\n<li>add support for async waitForTarget (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/7885">#7885</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/dbf0639822d0b2736993de52c0bfe1dbf4e58f25">dbf0639</a>)</li>\n<li>export <code>Frame._client</code> through getter (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/8041">#8041</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/e9278fcfcffe2558de63ce7542483445bcb6e74f">e9278fc</a>)</li>\n<li><strong>HTTPResponse:</strong> expose timing information (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/8025">#8025</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/30b3d49b0de46d812b7485e708174a07c73dbdd0">30b3d49</a>)</li>\n</ul>\n<h3>Bug Fixes</h3>\n<ul>\n<li>change kill to signal the whole process group to terminate  (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/6859">#6859</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/0eb9c7861717ebba7012c03e76b7a46063e4e5dd">0eb9c78</a>)</li>\n<li>element screenshot issue in headful mode (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/8018">#8018</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/5346e70ffc15b33c1949657cf1b465f1acc5d84d">5346e70</a>), closes <a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/7999">#7999</a></li>\n<li>ensure dom binding is not called after detach (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/8024">#8024</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/5c308b0704123736ddb085f97596c201ea18cf4a">5c308b0</a>), closes <a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/7814">#7814</a></li>\n<li>use both __dirname and require.resolve to support different bundlers (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/8046">#8046</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/e6a6295d9a7480bb59ee58a2cc7785171fa0fa2c">e6a6295</a>), closes <a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/8044">#8044</a></li>\n</ul>\n<h2>13.3.2</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>always use ENV executable path when present (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/7985">#7985</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/6d6ea9bf59daa3fb851b3da8baa27887e0aa2c28">6d6ea9b</a>)</li>\n<li>use require.resolve instead of __dirname (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/8003">#8003</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/bbb186d88cb99e4914299c983c822fa41a80f356">bbb186d</a>)</li>\n</ul>\n<h2>13.3.1</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>puppeteer:</strong> revert: esm modules (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/7986">#7986</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/179ededa1400c35c1f2edc015548e0f2a1bcee14">179eded</a>)</li>\n</ul>\n<h2>13.3.0</h2>\n<h3>Features</h3>\n<ul>\n<li><strong>puppeteer:</strong> export esm modules in package.json (<a href="https://github-redirect.dependabot.com/puppeteer/puppeteer/issues/7964">#7964</a>) (<a href="https://github.com/puppeteer/puppeteer/commit/523b487e8802824cecff86d256b4f7dbc4c47c8a">523b487</a>)</li>\ ...
#     'reactions': {'url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/920/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/920/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/comments/1061155586',
#     'html_url': 'https://github.com/yefoenix/RSSHub/pull/920#issuecomment-1061155586',
#     'issue_url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/920',
#     'id': 1061155586,
#     'node_id': 'IC_kwDOE6P1Xc4_P_MC',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2022-03-07T21:29:35Z',
#     'updated_at': '2022-03-07T21:29:35Z',
#     'author_association': 'NONE',
#     'body': 'Superseded by #950.',
#     'reactions': {'url': 'https://api.github.com/repos/yefoenix/RSSHub/issues/comments/1061155586/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025946',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 467265368,
#    'name': 'direwolf-github/ephemeral-ci-c43d901b',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-c43d901b'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025935',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 467265369,
#    'name': 'direwolf-github/ephemeral-ci-1443950c',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-1443950c'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025912',
#   'type': 'CreateEvent',
#   'actor': {'id': 21226554,
#    'login': 'omiinaya',
#    'display_login': 'omiinaya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/omiinaya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21226554?'},
#   'repo': {'id': 467265161,
#    'name': 'omiinaya/lostark-map-overlay',
#    'url': 'https://api.github.com/repos/omiinaya/lostark-map-overlay'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025930',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 11433410,
#    'name': 'amiel/active_admin',
#    'url': 'https://api.github.com/repos/amiel/active_admin'},
#   'payload': {'action': 'closed',
#    'number': 47,
#    'pull_request': {'url': 'https://api.github.com/repos/amiel/active_admin/pulls/47',
#     'id': 694717853,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Njk0NzE3ODUz',
#     'html_url': 'https://github.com/amiel/active_admin/pull/47',
#     'diff_url': 'https://github.com/amiel/active_admin/pull/47.diff',
#     'patch_url': 'https://github.com/amiel/active_admin/pull/47.patch',
#     'issue_url': 'https://api.github.com/repos/amiel/active_admin/issues/47',
#     'number': 47,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump cucumber-rails from 2.3.0 to 2.4.0 in /gemfiles/rails_61_turbolinks',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [cucumber-rails](https://github.com/cucumber/cucumber-rails) from 2.3.0 to 2.4.0.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/cucumber/cucumber-rails/releases">cucumber-rails\'s releases</a>.</em></p>\n<blockquote>\n<h2>v2.4.0</h2>\n<h3>New Features</h3>\n<ul>\n<li>Added new docker / Makefile script to permit releasing from repo</li>\n<li>Permit up to cucumber v7</li>\n<li>Support Ruby 3</li>\n</ul>\n<h3>Changed</h3>\n<ul>\n<li>Rubocop updates</li>\n</ul>\n<h3>Removed</h3>\n<ul>\n<li>Removed traces of legacy spork setup / help (As they are no longer used)</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/cucumber/cucumber-rails/blob/main/CHANGELOG.md">cucumber-rails\'s changelog</a>.</em></p>\n<blockquote>\n<h2><a href="https://github.com/cucumber/cucumber-rails/compare/v2.3.0...v2.4.0">v2.4.0</a> (2021-07-21)</h2>\n<h3>New Features</h3>\n<ul>\n<li>Added new docker / Makefile script to permit releasing from repo (<a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/pull/502">#502</a> [luke-hill])</li>\n<li>Gem update: allowed cucumber 6/7 (<a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/pull/515">#515</a> /\n<a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/pull/519">#519</a>)</li>\n<li>Add support for Ruby 3 (<a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/pull/517/">#517</a>)</li>\n</ul>\n<h3>Changed</h3>\n<ul>\n<li>Updated rubocop to use new major versions (<a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/pull/504">#504</a> /\n<a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/pull/519">#519</a> [luke-hill])</li>\n</ul>\n<h3>Removed</h3>\n<ul>\n<li>Removed traces of legacy spork setup / help (No longer used)  (<a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/pull/518">#518</a>)</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/2abac388d554f81631a724e0178ff093b35dad12"><code>2abac38</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/issues/520">#520</a> from cucumber/release/v2_4_0</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/7f158829c1574f085ac13d7caf79e19d3b064d33"><code>7f15882</code></a> v2.4.0</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/120af8bf4d882f9ea0bea0c42da5ce33810278ff"><code>120af8b</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/issues/518">#518</a> from DanielVartanov/remove-spork</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/e325f21cdb40bee5e64acda38cca3c46904d6402"><code>e325f21</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/cucumber/cucumber-rails/issues/519">#519</a> from cucumber/feature/update_deps</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/4c2ba0cdb381ac29dfdb538a3c518622870ee8d1"><code>4c2ba0c</code></a> Rubocop performance is also only 2.5+</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/434e1ffb7d74ef021b4557a6f160cc4d5e6819d1"><code>434e1ff</code></a> Downgrade from broken appraisals version</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/37f8552b3bde22f0471f411929e3ed09e7ba951f"><code>37f8552</code></a> Downgrade rubocop-rspec to be compatible with ruby 2.4</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/caa9b7f50a0179f047ea6e0370b0bc52e5c9eead"><code>caa9b7f</code></a> Update changelog</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/8d9109f9d03a4840eb1b021aabf60e2ccdcba583"><code>8d9109f</code></a> Update rubocop</li>\n<li><a href="https://github.com/cucumber/cucumber-rails/commit/7e2c378cc ...
#     'created_at': '2021-07-21T21:22:05Z',
#     'updated_at': '2022-03-07T21:29:35Z',
#     'closed_at': '2022-03-07T21:29:35Z',
#     'merged_at': None,
#     'merge_commit_sha': '1d3560fadf35cda73fa11a29f175400678b08792',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 3089405506,
#       'node_id': 'MDU6TGFiZWwzMDg5NDA1NTA2',
#       'url': 'https://api.github.com/repos/amiel/active_admin/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 3090777794,
#       'node_id': 'MDU6TGFiZWwzMDkwNzc3Nzk0',
#       'url': 'https://api.github.com/repos/amiel/active_admin/labels/ruby',
#       'name': 'ruby',
#       'color': 'ce2d2d',
#       'default': False,
#       'description': 'Pull requests that update Ruby code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/amiel/active_admin/pulls/47/commits',
#     'review_comments_url': 'https://api.github.com/repos/amiel/active_admin/pulls/47/comments',
#     'review_comment_url': 'https://api.github.com/repos/amiel/active_admin/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/amiel/active_admin/issues/47/comments',
#     'statuses_url': 'https://api.github.com/repos/amiel/active_admin/statuses/373677c00403c80c39517e0149d51bde09944939',
#     'head': {'label': 'amiel:dependabot/bundler/gemfiles/rails_61_turbolinks/cucumber-rails-2.4.0',
#      'ref': 'dependabot/bundler/gemfiles/rails_61_turbolinks/cucumber-rails-2.4.0',
#      'sha': '373677c00403c80c39517e0149d51bde09944939',
#      'user': {'login': 'amiel',
#       'id': 27160,
#       'node_id': 'MDQ6VXNlcjI3MTYw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/27160?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/amiel',
#       'html_url': 'https://github.com/amiel',
#       'followers_url': 'https://api.github.com/users/amiel/followers',
#       'following_url': 'https://api.github.com/users/amiel/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/amiel/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/amiel/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/amiel/subscriptions',
#       'organizations_url': 'https://api.github.com/users/amiel/orgs',
#       'repos_url': 'https://api.github.com/users/amiel/repos',
#       'events_url': 'https://api.github.com/users/amiel/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/amiel/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 11433410,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTQzMzQxMA==',
#       'name': 'active_admin',
#       'full_name': 'amiel/active_admin',
#       'private': False,
#       'owner': {'login': 'amiel',
#        'id': 27160,
#        'node_id': 'MDQ6VXNlcjI3MTYw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/27160?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/amiel',
#        'html_url': 'https://github.com/amiel',
#        'followers_url': 'https://api.github.com/users/amiel/followers',
#        'following_url': 'https://api.github.com/users/amiel/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/amiel/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/amiel/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/amiel/subscriptions',
#        'organizations_url': 'https://api.github.com/users/amiel/orgs',
#        'repos_url': 'https://api.github.com/users/amiel/repos',
#        'events_url': 'https://api.github.com/users/amiel/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/amiel/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/amiel/active_admin',
#       'description': 'The administration framework for Ruby on Rails applications.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/amiel/active_admin',
#       'forks_url': 'https://api.github.com/repos/amiel/active_admin/forks',
#       'keys_url': 'https://api.github.com/repos/amiel/active_admin/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/amiel/active_admin/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/amiel/active_admin/teams',
#       'hooks_url': 'https://api.github.com/repos/amiel/active_admin/hooks',
#       'issue_events_url': 'https://api.github.com/repos/amiel/active_admin/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/amiel/active_admin/events',
#       'assignees_url': 'https://api.github.com/repos/amiel/active_admin/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/amiel/active_admin/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/amiel/active_admin/tags',
#       'blobs_url': 'https://api.github.com/repos/amiel/active_admin/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/amiel/active_admin/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/amiel/active_admin/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/amiel/active_admin/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/amiel/active_admin/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/amiel/active_admin/languages',
#       'stargazers_url': 'https://api.github.com/repos/amiel/active_admin/stargazers',
#       'contributors_url': 'https://api.github.com/repos/amiel/active_admin/contributors',
#       'subscribers_url': 'https://api.github.com/repos/amiel/active_admin/subscribers',
#       'subscription_url': 'https://api.github.com/repos/amiel/active_admin/subscription',
#       'commits_url': 'https://api.github.com/repos/amiel/active_admin/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/amiel/active_admin/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/amiel/active_admin/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/amiel/active_admin/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/amiel/active_admin/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/amiel/active_admin/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/amiel/active_admin/merges',
#       'archive_url': 'https://api.github.com/repos/amiel/active_admin/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/amiel/active_admin/downloads',
#       'issues_url': 'https://api.github.com/repos/amiel/active_admin/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/amiel/active_admin/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/amiel/active_admin/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/amiel/active_admin/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/amiel/active_admin/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/amiel/active_admin/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/amiel/active_admin/deployments',
#       'created_at': '2013-07-15T20:50:02Z',
#       'updated_at': '2021-12-20T01:46:49Z',
#       'pushed_at': '2022-03-07T21:29:32Z',
#       'git_url': 'git://github.com/amiel/active_admin.git',
#       'ssh_url': 'git@github.com:amiel/active_admin.git',
#       'clone_url': 'https://github.com/amiel/active_admin.git',
#       'svn_url': 'https://github.com/amiel/active_admin',
#       'homepage': 'activeadmin.info',
#       'size': 11735,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 31,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 31,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'amiel:master',
#      'ref': 'master',
#      'sha': '9c7d2a10359d9643922eb9b0de3dc5cd391152cf',
#      'user': {'login': 'amiel',
#       'id': 27160,
#       'node_id': 'MDQ6VXNlcjI3MTYw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/27160?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/amiel',
#       'html_url': 'https://github.com/amiel',
#       'followers_url': 'https://api.github.com/users/amiel/followers',
#       'following_url': 'https://api.github.com/users/amiel/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/amiel/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/amiel/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/amiel/subscriptions',
#       'organizations_url': 'https://api.github.com/users/amiel/orgs',
#       'repos_url': 'https://api.github.com/users/amiel/repos',
#       'events_url': 'https://api.github.com/users/amiel/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/amiel/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 11433410,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTQzMzQxMA==',
#       'name': 'active_admin',
#       'full_name': 'amiel/active_admin',
#       'private': False,
#       'owner': {'login': 'amiel',
#        'id': 27160,
#        'node_id': 'MDQ6VXNlcjI3MTYw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/27160?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/amiel',
#        'html_url': 'https://github.com/amiel',
#        'followers_url': 'https://api.github.com/users/amiel/followers',
#        'following_url': 'https://api.github.com/users/amiel/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/amiel/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/amiel/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/amiel/subscriptions',
#        'organizations_url': 'https://api.github.com/users/amiel/orgs',
#        'repos_url': 'https://api.github.com/users/amiel/repos',
#        'events_url': 'https://api.github.com/users/amiel/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/amiel/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/amiel/active_admin',
#       'description': 'The administration framework for Ruby on Rails applications.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/amiel/active_admin',
#       'forks_url': 'https://api.github.com/repos/amiel/active_admin/forks',
#       'keys_url': 'https://api.github.com/repos/amiel/active_admin/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/amiel/active_admin/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/amiel/active_admin/teams',
#       'hooks_url': 'https://api.github.com/repos/amiel/active_admin/hooks',
#       'issue_events_url': 'https://api.github.com/repos/amiel/active_admin/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/amiel/active_admin/events',
#       'assignees_url': 'https://api.github.com/repos/amiel/active_admin/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/amiel/active_admin/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/amiel/active_admin/tags',
#       'blobs_url': 'https://api.github.com/repos/amiel/active_admin/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/amiel/active_admin/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/amiel/active_admin/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/amiel/active_admin/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/amiel/active_admin/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/amiel/active_admin/languages',
#       'stargazers_url': 'https://api.github.com/repos/amiel/active_admin/stargazers',
#       'contributors_url': 'https://api.github.com/repos/amiel/active_admin/contributors',
#       'subscribers_url': 'https://api.github.com/repos/amiel/active_admin/subscribers',
#       'subscription_url': 'https://api.github.com/repos/amiel/active_admin/subscription',
#       'commits_url': 'https://api.github.com/repos/amiel/active_admin/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/amiel/active_admin/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/amiel/active_admin/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/amiel/active_admin/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/amiel/active_admin/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/amiel/active_admin/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/amiel/active_admin/merges',
#       'archive_url': 'https://api.github.com/repos/amiel/active_admin/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/amiel/active_admin/downloads',
#       'issues_url': 'https://api.github.com/repos/amiel/active_admin/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/amiel/active_admin/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/amiel/active_admin/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/amiel/active_admin/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/amiel/active_admin/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/amiel/active_admin/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/amiel/active_admin/deployments',
#       'created_at': '2013-07-15T20:50:02Z',
#       'updated_at': '2021-12-20T01:46:49Z',
#       'pushed_at': '2022-03-07T21:29:32Z',
#       'git_url': 'git://github.com/amiel/active_admin.git',
#       'ssh_url': 'git@github.com:amiel/active_admin.git',
#       'clone_url': 'https://github.com/amiel/active_admin.git',
#       'svn_url': 'https://github.com/amiel/active_admin',
#       'homepage': 'activeadmin.info',
#       'size': 11735,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 31,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 31,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/amiel/active_admin/pulls/47'},
#      'html': {'href': 'https://github.com/amiel/active_admin/pull/47'},
# ...
#       'subscriptions_url': 'https://api.github.com/users/zjla/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zjla/orgs',
#       'repos_url': 'https://api.github.com/users/zjla/repos',
#       'events_url': 'https://api.github.com/users/zjla/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zjla/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 300586627,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMDA1ODY2Mjc=',
#       'name': 'RSSHub',
#       'full_name': 'zjla/RSSHub',
#       'private': False,
#       'owner': {'login': 'zjla',
#        'id': 32954686,
#        'node_id': 'MDQ6VXNlcjMyOTU0Njg2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/32954686?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/zjla',
#        'html_url': 'https://github.com/zjla',
#        'followers_url': 'https://api.github.com/users/zjla/followers',
#        'following_url': 'https://api.github.com/users/zjla/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/zjla/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/zjla/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/zjla/subscriptions',
#        'organizations_url': 'https://api.github.com/users/zjla/orgs',
#        'repos_url': 'https://api.github.com/users/zjla/repos',
#        'events_url': 'https://api.github.com/users/zjla/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/zjla/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/zjla/RSSHub',
#       'description': '🍰 Everything is RSSible',
#       'fork': True,
#       'url': 'https://api.github.com/repos/zjla/RSSHub',
#       'forks_url': 'https://api.github.com/repos/zjla/RSSHub/forks',
#       'keys_url': 'https://api.github.com/repos/zjla/RSSHub/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/zjla/RSSHub/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/zjla/RSSHub/teams',
#       'hooks_url': 'https://api.github.com/repos/zjla/RSSHub/hooks',
#       'issue_events_url': 'https://api.github.com/repos/zjla/RSSHub/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/zjla/RSSHub/events',
#       'assignees_url': 'https://api.github.com/repos/zjla/RSSHub/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/zjla/RSSHub/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/zjla/RSSHub/tags',
#       'blobs_url': 'https://api.github.com/repos/zjla/RSSHub/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/zjla/RSSHub/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/zjla/RSSHub/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/zjla/RSSHub/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/zjla/RSSHub/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/zjla/RSSHub/languages',
#       'stargazers_url': 'https://api.github.com/repos/zjla/RSSHub/stargazers',
#       'contributors_url': 'https://api.github.com/repos/zjla/RSSHub/contributors',
#       'subscribers_url': 'https://api.github.com/repos/zjla/RSSHub/subscribers',
#       'subscription_url': 'https://api.github.com/repos/zjla/RSSHub/subscription',
#       'commits_url': 'https://api.github.com/repos/zjla/RSSHub/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/zjla/RSSHub/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/zjla/RSSHub/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/zjla/RSSHub/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/zjla/RSSHub/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/zjla/RSSHub/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/zjla/RSSHub/merges',
#       'archive_url': 'https://api.github.com/repos/zjla/RSSHub/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/zjla/RSSHub/downloads',
#       'issues_url': 'https://api.github.com/repos/zjla/RSSHub/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/zjla/RSSHub/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/zjla/RSSHub/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/zjla/RSSHub/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/zjla/RSSHub/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/zjla/RSSHub/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/zjla/RSSHub/deployments',
#       'created_at': '2020-10-02T10:59:39Z',
#       'updated_at': '2022-01-08T14:23:27Z',
#       'pushed_at': '2022-03-07T21:29:31Z',
#       'git_url': 'git://github.com/zjla/RSSHub.git',
#       'ssh_url': 'git@github.com:zjla/RSSHub.git',
#       'clone_url': 'https://github.com/zjla/RSSHub.git',
#       'svn_url': 'https://github.com/zjla/RSSHub',
#       'homepage': 'https://docs.rsshub.app',
#       'size': 66774,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 12,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'zjla:master',
#      'ref': 'master',
#      'sha': '050e72b67cc4ff9bc7324db36be155b4ba880673',
#      'user': {'login': 'zjla',
#       'id': 32954686,
#       'node_id': 'MDQ6VXNlcjMyOTU0Njg2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/32954686?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/zjla',
#       'html_url': 'https://github.com/zjla',
#       'followers_url': 'https://api.github.com/users/zjla/followers',
#       'following_url': 'https://api.github.com/users/zjla/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/zjla/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/zjla/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/zjla/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zjla/orgs',
#       'repos_url': 'https://api.github.com/users/zjla/repos',
#       'events_url': 'https://api.github.com/users/zjla/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zjla/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 300586627,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMDA1ODY2Mjc=',
#       'name': 'RSSHub',
#       'full_name': 'zjla/RSSHub',
#       'private': False,
#       'owner': {'login': 'zjla',
#        'id': 32954686,
#        'node_id': 'MDQ6VXNlcjMyOTU0Njg2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/32954686?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/zjla',
#        'html_url': 'https://github.com/zjla',
#        'followers_url': 'https://api.github.com/users/zjla/followers',
#        'following_url': 'https://api.github.com/users/zjla/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/zjla/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/zjla/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/zjla/subscriptions',
#        'organizations_url': 'https://api.github.com/users/zjla/orgs',
#        'repos_url': 'https://api.github.com/users/zjla/repos',
#        'events_url': 'https://api.github.com/users/zjla/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/zjla/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/zjla/RSSHub',
#       'description': '🍰 Everything is RSSible',
#       'fork': True,
#       'url': 'https://api.github.com/repos/zjla/RSSHub',
#       'forks_url': 'https://api.github.com/repos/zjla/RSSHub/forks',
#       'keys_url': 'https://api.github.com/repos/zjla/RSSHub/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/zjla/RSSHub/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/zjla/RSSHub/teams',
#       'hooks_url': 'https://api.github.com/repos/zjla/RSSHub/hooks',
#       'issue_events_url': 'https://api.github.com/repos/zjla/RSSHub/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/zjla/RSSHub/events',
#       'assignees_url': 'https://api.github.com/repos/zjla/RSSHub/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/zjla/RSSHub/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/zjla/RSSHub/tags',
#       'blobs_url': 'https://api.github.com/repos/zjla/RSSHub/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/zjla/RSSHub/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/zjla/RSSHub/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/zjla/RSSHub/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/zjla/RSSHub/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/zjla/RSSHub/languages',
#       'stargazers_url': 'https://api.github.com/repos/zjla/RSSHub/stargazers',
#       'contributors_url': 'https://api.github.com/repos/zjla/RSSHub/contributors',
#       'subscribers_url': 'https://api.github.com/repos/zjla/RSSHub/subscribers',
#       'subscription_url': 'https://api.github.com/repos/zjla/RSSHub/subscription',
#       'commits_url': 'https://api.github.com/repos/zjla/RSSHub/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/zjla/RSSHub/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/zjla/RSSHub/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/zjla/RSSHub/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/zjla/RSSHub/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/zjla/RSSHub/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/zjla/RSSHub/merges',
#       'archive_url': 'https://api.github.com/repos/zjla/RSSHub/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/zjla/RSSHub/downloads',
#       'issues_url': 'https://api.github.com/repos/zjla/RSSHub/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/zjla/RSSHub/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/zjla/RSSHub/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/zjla/RSSHub/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/zjla/RSSHub/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/zjla/RSSHub/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/zjla/RSSHub/deployments',
#       'created_at': '2020-10-02T10:59:39Z',
#       'updated_at': '2022-01-08T14:23:27Z',
#       'pushed_at': '2022-03-07T21:29:31Z',
#       'git_url': 'git://github.com/zjla/RSSHub.git',
#       'ssh_url': 'git@github.com:zjla/RSSHub.git',
#       'clone_url': 'https://github.com/zjla/RSSHub.git',
#       'svn_url': 'https://github.com/zjla/RSSHub',
#       'homepage': 'https://docs.rsshub.app',
#       'size': 66774,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 12,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/zjla/RSSHub/pulls/1074'},
#      'html': {'href': 'https://github.com/zjla/RSSHub/pull/1074'},
#      'issue': {'href': 'https://api.github.com/repos/zjla/RSSHub/issues/1074'},
#      'comments': {'href': 'https://api.github.com/repos/zjla/RSSHub/issues/1074/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/zjla/RSSHub/pulls/1074/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/zjla/RSSHub/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/zjla/RSSHub/pulls/1074/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/zjla/RSSHub/statuses/f7f383ef0115b343c50609a5832a2b31b9ae214f'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 4,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 12,
#     'deletions': 7,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'},
#  {'id': '20625025876',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 275449361,
#    'name': 'dsbbfinddx/FINDCov19TrackerData',
#    'url': 'https://api.github.com/repos/dsbbfinddx/FINDCov19TrackerData'},
#   'payload': {'push_id': 9288818848,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '630fca9319296d70545a7616bc6b88af82b4680b',
#    'before': 'c97792e2aaaa359e3cab16d0cb22872b4db53420',
#    'commits': [{'sha': '630fca9319296d70545a7616bc6b88af82b4680b',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'update segregated files for 2022-03-07',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dsbbfinddx/FINDCov19TrackerData/commits/630fca9319296d70545a7616bc6b88af82b4680b'}]},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z',
#   'org': {'id': 67270498,
#    'login': 'dsbbfinddx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dsbbfinddx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67270498?'}},
#  {'id': '20625025848',
#   'type': 'PushEvent',
#   'actor': {'id': 99505478,
#    'login': 'Koech6508',
#    'display_login': 'Koech6508',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Koech6508',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99505478?'},
#   'repo': {'id': 465419068,
#    'name': 'Koech6508/alx-system_engineering-devops',
#    'url': 'https://api.github.com/repos/Koech6508/alx-system_engineering-devops'},
#   'payload': {'push_id': 9288818833,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f44c584f31528ba5b6628937c64a2c51ee1a523a',
#    'before': '008b4d1bb735d27486f31d4d4cbc4bc83897d364',
#    'commits': [{'sha': 'f44c584f31528ba5b6628937c64a2c51ee1a523a',
#      'author': {'email': 'koechdebora@gmail.co', 'name': 'Koech 6508'},
#      'message': 'xyz',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Koech6508/alx-system_engineering-devops/commits/f44c584f31528ba5b6628937c64a2c51ee1a523a'}]},
#   'public': True,
#   'created_at': '2022-03-07T21:29:35Z'}]

# %%
r.json()[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at'])

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = 'https://pokeapi.co/api/v2/pokemon/'

# %%
# How does that need to adapt for charmander?

charmander_url = base_poke_url + '4/'
charmander_url
# Out:
# 'https://pokeapi.co/api/v2/pokemon/4/'

# %%
##Or u can do it like this:

charmander_url = base_poke_url + 'charmander'
charmander_url
# Out:
# 'https://pokeapi.co/api/v2/pokemon/charmander'

# %%
# Check the status code, will this work?

resp = requests.get(charmander_url)
resp.status_code
# Out:
# 200

# %%
# Now let's actually get the response (as a json)

char_json = resp.json()

# %%
# Let's check out some details about the response

char_json.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
# Check the id

char_json['id']
# Out:
# 4

# %%
# Check the name
char_json['name']
# Out:
# 'charmander'

# %%
# Check the types
char_json['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %% [markdown]
# #### Helper Function!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type _and secondary type_ for that pokemon.
#
# Note that Charmander here just has one type - what would a pokemon with two types look like? Note that Bulbasaur is both grass and poison types.

# %%
# Code here to explore

bulba_url = base_poke_url + '1/'  ## use the '1/' to append that to the end of the string
bulba = requests.get(bulba_url).json()
bulba['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#  {'slot': 2,
#   'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    
    if secondary type is not applicable, secondary type will be 'None'
    '''
    poke_id = poke_resp['id']
    
    poke_name = poke_resp['name']
    
    primary_type = poke_resp['types'][0]['type']['name']
    
    if len(poke_resp['types']) == 1:
        secondary_type = 'None'
    else: 
        secondary_type = poke_resp['types'][1]['type']['name']
        
    poke_details_list = [poke_id, poke_name, primary_type, secondary_type]
        
    return poke_details_list

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
# Run this code to check our work
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', 'None']
# [7, 'squirtle', 'water', 'None']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import panda
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the `time` library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!
# Let's write this together!

for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(.5)


    
# Then, concat everything into one df
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df.tail()
# Out:
#       id       name primary_type secondary_type
# 146  147    dratini       dragon           None
# 147  148  dragonair       dragon           None
# 148  149  dragonite       dragon         flying
# 149  150     mewtwo      psychic           None
# 150  151        mew      psychic           None

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Define a function to open the json

def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 

api_keys = get_keys(##enter the path of where the json file is located)

# Setting the first (and only) value as a variable
tmdb_1 = api_keys['tmdb_key']  ## DO NOT LEAVE API AS AN OUTPUT!##
# Out:
#   File "<ipython-input-30-9e9d21b9c940>", line 18
#     tmdb_1 = api_keys['tmdb_key']  ## DO NOT LEAVE API AS AN OUTPUT!##
#                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from keys import tmdb_key




# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!

example_url = f'https://api.themoviedb.org/3/movie/550?api_key={tmdb_key}'

# %%
# Get the response

r = requests.get(example_url).json()

# %%
# Check the keys

r.keys()
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'])

# %%
r
# Out:
# {'adult': False,
#  'backdrop_path': '/rr7E0NoGKxvbkb89eR1GwfoYjpA.jpg',
#  'belongs_to_collection': None,
#  'budget': 63000000,
#  'genres': [{'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.foxmovies.com/movies/fight-club',
#  'id': 550,
#  'imdb_id': 'tt0137523',
#  'original_language': 'en',
#  'original_title': 'Fight Club',
#  'overview': 'A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.',
#  'popularity': 66.627,
#  'poster_path': '/pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg',
#  'production_companies': [{'id': 508,
#    'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png',
#    'name': 'Regency Enterprises',
#    'origin_country': 'US'},
#   {'id': 711,
#    'logo_path': '/tEiIH5QesdheJmDAqQwvtN60727.png',
#    'name': 'Fox 2000 Pictures',
#    'origin_country': 'US'},
#   {'id': 20555,
#    'logo_path': '/hD8yEGUBlHOcfHYbujp71vD8gZp.png',
#    'name': 'Taurus Film',
#    'origin_country': 'DE'},
#   {'id': 54051,
#    'logo_path': None,
#    'name': 'Atman Entertainment',
#    'origin_country': ''},
#   {'id': 54052,
#    'logo_path': None,
#    'name': 'Knickerbocker Films',
#    'origin_country': 'US'},
#   {'id': 4700,
#    'logo_path': '/A32wmjrs9Psf4zw0uaixF0GXfxq.png',
#    'name': 'The Linson Company',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '1999-10-15',
#  'revenue': 100853753,
#  'runtime': 139,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Mischief. Mayhem. Soap.',
#  'title': 'Fight Club',
#  'video': False,
#  'vote_average': 8.4,
#  'vote_count': 23613}

# %%
example_id = r['id']
example_id
# Out:
# 550

# %%
# Find similar movies to the previous id

base_url = 'https://api.themoviedb.org/3/'

similar_movie_url = f'{base_url}/movie/{example_id}/similar?api_key={tmdb_key}'

# %%
# Check out that response

r = requests.get(similar_movie_url).json()

# %%
r.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
# How many similar movies did it find?

r['total_results']
# Out:
# 10000

# %%
# but is that the length of these results?

len(r['results'])
# Out:
# 20

# %%
# what's in here?

r['results'][0]
# Out:
# {'adult': False,
#  'backdrop_path': '/duC9QWccFMy8HNjDWgYeWcKoiw.jpg',
#  'genre_ids': [18, 10749, 10752],
#  'id': 22971,
#  'title': 'Dear John',
#  'original_language': 'en',
#  'original_title': 'Dear John',
#  'overview': "While Sergeant John Tyree is home on two weeks leave from Germany, he meets Savannah after he dives into the ocean to retrieve Savannah's purse that had fallen off a pier. John eventually falls in love with Savannah, who promises to write to him until he returns from overseas.",
#  'popularity': 23.897,
#  'poster_path': '/2lAPv2jQ5eh54l4EttA9wjDljED.jpg',
#  'release_date': '2010-02-04',
#  'video': False,
#  'vote_average': 6.852,
#  'vote_count': 3650}

# %% [markdown]
# ## Level Up - Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit - Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
